# %% [markdown]
# <a href="https://colab.research.google.com/github/swaroop116/machine-learning-learn/blob/main/KMeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.datasets import load_iris
data=load_iris()
df=pd.DataFrame(data.data,columns=data.feature_names)
df.drop(['sepal width (cm)','sepal length (cm)'], axis='columns',inplace=True)

# %%
df
# Out:
#      petal length (cm)  petal width (cm)
# 0                  1.4               0.2
# 1                  1.4               0.2
# 2                  1.3               0.2
# 3                  1.5               0.2
# 4                  1.4               0.2
# ..                 ...               ...
# 145                5.2               2.3
# 146                5.0               1.9
# 147                5.2               2.0
# 148                5.4               2.3
# 149                5.1               1.8
#
# [150 rows x 2 columns]

# %%
from sklearn.cluster import KMeans
model =KMeans(n_clusters=3)
jk=model.fit_predict(df)
df['cluster']=jk
df
# Out:
#      petal length (cm)  petal width (cm)  cluster
# 0                  1.4               0.2        1
# 1                  1.4               0.2        1
# 2                  1.3               0.2        1
# 3                  1.5               0.2        1
# 4                  1.4               0.2        1
# ..                 ...               ...      ...
# 145                5.2               2.3        0
# 146                5.0               1.9        0
# 147                5.2               2.0        0
# 148                5.4               2.3        0
# 149                5.1               1.8        0
#
# [150 rows x 3 columns]

# %%
ar=model.cluster_centers_
ar
# Out:
# array([[5.59583333, 2.0375    ],
#        [1.462     , 0.246     ],
#        [4.26923077, 1.34230769]])

# %%
from matplotlib import pyplot as plt
df1=df[df.cluster==0]
df2=df[df.cluster==1]
df3=df[df.cluster==2]
plt.scatter(df2['petal length (cm)'],df2['petal width (cm)'],color='blue')
plt.scatter(df3['petal length (cm)'],df3['petal width (cm)'],color="red")
plt.scatter(df1['petal length (cm)'],df1['petal width (cm)'],color="green")
plt.scatter(ar[:,0],ar[:,1],marker="+",color="black")

# %%
sse=[]
krange=range(1,10)
for i in krange:
  jc=KMeans(n_clusters=i)
  il=jc.fit(df)
  sse.append(il.inertia_)

# %%
plt.plot(krange,sse)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
df
# Out:
#      petal length (cm)  petal width (cm)  cluster
# 0                  1.4               0.2        1
# 1                  1.4               0.2        1
# 2                  1.3               0.2        1
# 3                  1.5               0.2        1
# 4                  1.4               0.2        1
# ..                 ...               ...      ...
# 145                5.2               2.3        0
# 146                5.0               1.9        0
# 147                5.2               2.0        0
# 148                5.4               2.3        0
# 149                5.1               1.8        0
#
# [150 rows x 3 columns]
